# %% [markdown]
# # Python Problem Solution
# Solution to the problem given by Midas - IIITD. <br>
#
# The task is to fetch all the tweets done by midas@IIITD twitter handle and dump the responses into JSONlines file.
#
# Then the file must be parsed to display the tweets in tabular format.

# %% [markdown]
# # Importing libraries

# %% [markdown]
# Installing the python-twitter and jsonlines libraries

# %%
# !pip install python-twitter
# !pip install jsonlines
# Out:
# Collecting python-twitter
#   Downloading https://files.pythonhosted.org/packages/b3/a9/2eb36853d8ca49a70482e2332aa5082e09b3180391671101b1612e3aeaf1/python_twitter-3.5-py2.py3-none-any.whl (67kB)
#     100% |████████████████████████████████| 71kB 2.7MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-twitter) (0.16.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from python-twitter) (1.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from python-twitter) (2.18.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->python-twitter) (3.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (2019.3.9)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->python-twitter) (1.22)
# Installing collected packages: python-twitter
# Successfully installed python-twitter-3.5
# Collecting jsonlines
#   Downloading https://files.pythonhosted.org/packages/4f/9a/ab96291470e305504aa4b7a2e0ec132e930da89eb3ca7a82fbe03167c131/jsonlines-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from jsonlines) (1.11.0)
# Installing collected packages: jsonlines
# Successfully installed jsonlines-1.2.0

# %% [markdown]
# Importing the required libraries for fetching tweets as well as generating jsonlines file as well as other important ones.

# %%
#Importing libraries

import twitter
import jsonlines
import pandas as pd

import sys
import io

# %% [markdown]
# # Defining keys and constants

# %% [markdown]
# Add required keys below

# %%
CONSUMER_KEY = 'consumer_key_here'
CONSUMER_SECRET = 'consumer_secret_here'
ACCESS_TOKEN = 'access_token_here'
ACCESS_TOKEN_SECRET = 'access_token_secret_here'

# %% [markdown]
# Name of twitter handle from where to fetch tweets and output path of jsonlines file

# %%
MIDAS_SCREEN_NAME = 'midasIIITD'

output_path = "output.jsonl"

# %% [markdown]
# # Fetching tweets

# %% [markdown]
# Creating a API Client to interact with the twitter API
#
# Using the python-twitter library it becomes simpler to interact with the Twitter API through pre - defined functions.
#
# The below block will initialize the client using the various keys.
#
# tweet_mode = 'extended' ensures that the entire tweet text is fetched and not truncated.

# %%
api = twitter.Api(consumer_key = CONSUMER_KEY,
                  consumer_secret=CONSUMER_SECRET,
                  access_token_key=ACCESS_TOKEN,
                  access_token_secret=ACCESS_TOKEN_SECRET,
                  tweet_mode='extended')

# %% [markdown]
# The function fetch_tweets will fetch all the tweets (as many as possible) from the given screen_name

# %%
def fetch_tweets(screen_name):
  tweet_list = api.GetUserTimeline(screen_name=screen_name, count=200) #fetch first 200 tweets
  print(tweet_list)
  earliest_tweet = min(tweet_list, key=lambda x: x.id).id  #find id of earliest tweet fetched
  
  #repeat above process till all tweets have been fetched
  while True:
    tweets = api.GetUserTimeline(screen_name=screen_name, count=200, max_id = earliest_tweet)
    new_earliest_tweet = min(tweets, key=lambda x: x.id).id
    
    #break loop if no more tweets left
    if new_earliest_tweet == earliest_tweet or not tweets :
      break
    else:
      earliest_tweet = new_earliest_tweet
      tweet_list += tweets
      
  return tweet_list  #returns all the tweets fetched

# %% [markdown]
# Fetch tweets for required screen name
#
# Here we have found 297 tweets

# %%
tweets = fetch_tweets(MIDAS_SCREEN_NAME)
print(len(tweets))
# Out:
# [Status(ID=1108281874164658182, ScreenName=midasIIITD, Created=Wed Mar 20 08:19:24 +0000 2019, Text='@IEEEBigMM19 is also available on Facebook now. \nLIKE its Facebook page https://t.co/B3Q0zmmzXb  to get the regular updates. \nCheck more details at https://t.co/w9ZymoPisk \n\n#IEEE #BigMM19 #Big #Multimedia #Singapore'), Status(ID=1108196492139999233, ScreenName=midasIIITD, Created=Wed Mar 20 02:40:07 +0000 2019, Text='RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals  \n\nhttps://t.co/I4vqf8FE6K …  \nWhen: Sep 11, 2019 - Sep 13, 201…'), Status(ID=1107468609914208256, ScreenName=midasIIITD, Created=Mon Mar 18 02:27:47 +0000 2019, Text='BigMM 2019 : IEEE BigMM 2019 – Call for Workshop Proposals\n\nhttps://t.co/oUq2G0UgKN\n\nWhen: Sep 11, 2019 - Sep 13, 2019\nWhere: Singapore\nSubmission Deadline: Apr 1, 2019\nNotification Due: Apr 10, 2019\n\n#IEEE #BigMM #Workshop #Proposal #Singapore #Multimedia'), Status(ID=1107285980082569218, ScreenName=midasIIITD, Created=Sun Mar 17 14:22:04 +0000 2019, Text='Congratulations @midasIIITD team, Rohan, Pradyumn, Ramit, @debanjanbhucs, @MADAIguy and @RatnRajiv for getting their paper titled, "SNAP-BATNET: Cascading Author Profiling and Social Network Graphs for Suicide Ideation Detection on Social Media", accepted at @NAACLHLT SRW.'), Status(ID=1106919781616091136, ScreenName=midasIIITD, Created=Sat Mar 16 14:06:56 +0000 2019, Text='We have emailed the task details to all shortlisted candidates for @midasIIITD internship. Kindly check the same. \n\nIf you are one of the shortlisted candidates and have not received the email then check your SPAM first before approaching. \n\n#MIDAS #Summer #Research #Internship'), Status(ID=1106847696327827456, ScreenName=midasIIITD, Created=Sat Mar 16 09:20:29 +0000 2019, Text='IEEE BigMM 2019 - Call for Workshop Proposals. \n\nContact @midasIIITD @RatnRajiv @debanjanbhucs if you have any query. \n\nDeadlines: \n- Proposals due: April 1, 2019\n- Acceptance notification: April 10, 2019\n\nFurther information:\n- Webpage: https://t.co/5XX5Wyxp5T\n\n#IEEE #BigMM19'), Status(ID=1106846308021596161, ScreenName=midasIIITD, Created=Sat Mar 16 09:14:58 +0000 2019, Text='Congratulations! Arijit, Ramit, @debanjanbhucs @RatnRajiv for your @NAACLHLT  @naacl SRW 2019 paper, "Speak Up, Fight Back! Detection of Social Media Disclosures of Sexual Harassment". \n\nCheck more details at https://t.co/i6eAHg7gcN\n\n#MeToo #Student #Research  #Paper #NAACL'), Status(ID=1106785474146791424, ScreenName=midasIIITD, Created=Sat Mar 16 05:13:14 +0000 2019, Text='We will be releasing a very interesting task to shortlisted candidates for the internship at @midasIIITD today. You will be having 10 days to solve the same. You will get a detailed email on the task and submission instruction today. Looking forward to your out of box solution.'), Status(ID=1105878620499644416, ScreenName=midasIIITD, Created=Wed Mar 13 17:09:44 +0000 2019, Text='RT @hcdiiitd: Last day to register for #PortfolioCreationinDesign Workshop Indraprastha Institute of Information Technology, Delhi on 15th…'), Status(ID=1105682747916324865, ScreenName=midasIIITD, Created=Wed Mar 13 04:11:24 +0000 2019, Text='@ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm @Benoit_Huet @RatnRajiv @kelkalot \nWe need to clearly mention abstract and final submission deadlines at https://t.co/U7DTNNyw87\n\nCurrently, we have just mentioned 1st April as the regular paper submission deadline. Kindly update. \n\n#ACMMM19 #Nice #Multimedia https://t.co/ocOCrlFHLH'), Status(ID=1105681404845670401, ScreenName=midasIIITD, Created=Wed Mar 13 04:06:04 +0000 2019, Text='RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…'), Status(ID=1105524793024147458, ScreenName=midasIIITD, Created=Tue Mar 12 17:43:44 +0000 2019, Text='RT @kaggle: Bookmark this amazing library of image augmentations 😵 by #Kaggle Masters @AlBusla ...
# 297

# %% [markdown]
# Showing the contents of one of the tweets in the form of a dict.

# %%
print(tweets[10].AsDict())
# Out:
# {'created_at': 'Wed Mar 13 04:06:04 +0000 2019', 'full_text': 'RT @ACMMM19: The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of…', 'hashtags': [], 'id': 1105681404845670401, 'id_str': '1105681404845670401', 'lang': 'en', 'retweet_count': 13, 'retweeted_status': {'created_at': 'Tue Mar 12 10:19:41 +0000 2019', 'favorite_count': 14, 'full_text': 'The paper deadline is approaching. 1 April abstract is due. Authors will have until 8 April to upload the final PDF version of their paper submission. For complete submission information, see https://t.co/zKyqPAxErM @sigmm @TheOfficialACM @acmmmsys @ACMTVX @ACMICMR @euromm', 'hashtags': [], 'id': 1105413041456328705, 'id_str': '1105413041456328705', 'lang': 'en', 'retweet_count': 13, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'urls': [{'expanded_url': 'http://www.acmmm.org/2019/call-for-papers', 'url': 'https://t.co/zKyqPAxErM'}], 'user': {'created_at': 'Fri Feb 09 14:54:25 +0000 2018', 'default_profile': True, 'description': 'The 27th ACM International Conference on Multimedia, October 21-25, 2019', 'favourites_count': 5, 'followers_count': 153, 'friends_count': 8, 'id': 961976587246817280, 'id_str': '961976587246817280', 'lang': 'en', 'listed_count': 5, 'location': 'Nice, France', 'name': 'ACMMM19', 'profile_background_color': 'F5F8FA', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/961976587246817280/1518188442', 'profile_image_url': 'http://pbs.twimg.com/profile_images/961981050481192960/MLwpsHQb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961981050481192960/MLwpsHQb_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'screen_name': 'ACMMM19', 'statuses_count': 15}, 'user_mentions': [{'id': 191650709, 'id_str': '191650709', 'name': 'ACM SIGMM', 'screen_name': 'sigmm'}, {'id': 115763683, 'id_str': '115763683', 'name': 'Official ACM', 'screen_name': 'TheOfficialACM'}, {'id': 891320104977395712, 'id_str': '891320104977395712', 'name': 'ACM MMsys Conference', 'screen_name': 'acmmmsys'}, {'id': 1667459394, 'id_str': '1667459394', 'name': 'ACM TVX', 'screen_name': 'ACMTVX'}, {'id': 169852874, 'id_str': '169852874', 'name': 'ACM ICMR', 'screen_name': 'ACMICMR'}, {'id': 518457662, 'id_str': '518457662', 'name': 'euromm', 'screen_name': 'euromm'}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'urls': [], 'user': {'created_at': 'Mon Jul 23 11:26:04 +0000 2018', 'default_profile': True, 'description': 'MIDAS is a group of researchers at IIIT-Delhi who study, analyze, and build different multimedia systems for society leveraging multimodal information.', 'favourites_count': 118, 'followers_count': 177, 'friends_count': 39, 'id': 1021355762575073281, 'id_str': '1021355762575073281', 'lang': 'en', 'location': 'New Delhi, India', 'name': 'MIDAS IIITD', 'profile_background_color': 'F5F8FA', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1021355762575073281/1552394509', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021356444921212928/WmSTJCUs_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'screen_name': 'midasIIITD', 'statuses_count': 296, 'url': 'https://t.co/Uwg7oSM6mE'}, 'user_mentions': [{'id': 961976587246817280, 'id_str': '961976587246817280', 'name': 'ACMMM19', 'screen_name': 'ACMMM19'}]}

# %% [markdown]
# Using the jsonlines library to dump the response in a JSONlines file output.jsonl

# %%
fp = open(output_path, "w")
with jsonlines.Writer(fp) as writer:
    for t in tweets:
      writer.write(t.AsDict())
fp.close()

# %% [markdown]
# # Parsing and Displaying tweets

# %% [markdown]
# Parse the output.jsonl file using library
#
# Put data required in a pandas DataFrame
# The fields are-
# - The text of the tweet.
# - Date and time of the tweet.
# - The number of favorites/likes.
# - The number of retweets.
# - Number of Images present in Tweet. If no image returns None.

# %%
#Read output file
fp = open(output_path, "r")
reader = jsonlines.Reader(fp)

#Create new df
df = pd.DataFrame(columns = ['text', 'date_time', 'favorites', 'retweets', 'num_images'])

#Fill table from file
for obj in reader.iter(type=dict, skip_invalid=True):
  row = {
      'text': obj["full_text"],
      'date_time': obj["created_at"],
      'favorites': obj["favorite_count"] if "favorite_count" in obj else 0,
      'retweets': obj["retweet_count"] if "retweet_count" in obj else 0,
      'num_images': len(obj["media"]) if 'media' in obj else None
  }
  df = df.append(row, ignore_index = True)

# %% [markdown]
# Displaying the data in tabular format

# %%
df.head(100)
# Out:
#                                                  text  \
# 0   @IEEEBigMM19 is also available on Facebook now...
# 1   RT @IEEEBigMM19: BigMM 2019 : IEEE BigMM 2019 ...
# 2   BigMM 2019 : IEEE BigMM 2019 – Call for Worksh...
# 3   Congratulations @midasIIITD team, Rohan, Prady...
# 4   We have emailed the task details to all shortl...
# 5   IEEE BigMM 2019 - Call for Workshop Proposals....
# 6   Congratulations! Arijit, Ramit, @debanjanbhucs...
# 7   We will be releasing a very interesting task t...
# 8   RT @hcdiiitd: Last day to register for #Portfo...
# 9   @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACM...
# 10  RT @ACMMM19: The paper deadline is approaching...
# 11  RT @kaggle: Bookmark this amazing library of i...
# 12  Awesome members of our @midasIIITD team who ar...
# 13      @saanidhi @ACMMM19 Before Friday, 15th March.
# 14  We are glad to inform that Adobe is launching ...
# 15  We will email tasks to all shortlisted candida...
# 16  @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less...
# 17  RT @kdnuggets: Face Recognition using One-Shot...
# 18  @AvinashSwamina2 @IIITDelhi No. They will be g...
# 19  We are in the process of finalizing the shortl...
# 20  @ylecun @NilayShri @the_dhumketu @debanjanbhuc...
# 21  RT @kdnuggets: Python Data Science for Beginne...
# 22  RT @stanfordnlp: Useful feature of our Python ...
# 23  @NilayShri @NilayShri, Certain thing! The next...
# 24  At @midasIIITD, we not only work hard but also...
# 25  Considering several requests to extend the dea...
# 26  RT @jeremyphoward: 39 studies about human perc...
# 27            Correction:   @midasIIITD at @IIITDelhi
# 28  Thanks much to all aspirants who have applied ...
# 29  RT @kdnuggets: Keras Hyperparameter Tuning in ...
# ..                                                ...
# 70  @RealAAAI 2019 summary for @midasIIITD.\n1 pap...
# 71  @the_dhumketu @RealAAAI Congrats! Raghav, Kshi...
# 72  Our paper titled, "Mind Your Language: Abuse a...
# 73  RT @PeterMartigny: Very interesting talk by @C...
# 74  RT @NilayShri: @midasIIITD @RatnRajiv\n@the_dh...
# 75  CFP for @ACMMM19 has been posted on WikiCFP. K...
# 76  @midasIIITD Lab is pleased to share our novel ...
# 77  RT @RatnRajiv: If you are attending @RealAAAI ...
# 78  RT @RatnRajiv: Great to be part of this year's...
# 79  RT @MIT: Want to squelch fake news? Let the re...
# 80  If you are attending @RealAAAI 2019 at Honolul...
# 81  If you are attending @RealAAAI 2019 then visit...
# 82  If you are attending @RealAAAI 2019 then visit...
# 83  If you are attending @RealAAAI 2019 then visit...
# 84  @TechAtBloomberg @debanjanbhucs It is a great ...
# 85  RT @TechAtBloomberg: Learn more about the coll...
# 86  RT @debanjanbhucs: We as researchers working a...
# 87  RT @kdnuggets: 7 Steps to Mastering Basic Mach...
# 88  @TechAtBloomberg @debanjanbhucs @IIITDelhi @Ra...
# 89  RT @TechAtBloomberg: #Textanalytics researcher...
# 90  RT @kdnuggets: Top 16 #OpenSource #DeepLearnin...
# 91  RT @Princeton: Using data from more than 6,000...
# 92  RT @CornellBirds: In 1929 Cornell Lab founder ...
# 93  RT @seb_ruder: Natural Questions: A new QA dat...
# 94  RT @kdnuggets: 10 More #Free Must-Read #Books ...
# 95  RT @kdnuggets: How to build an API for a machi...
# 96  @ACMMM19 @ACM @abhinavdhall consider submittin...
# 97  RT @ACMMM19: Jump start your @ACM #Multimedia ...
# 98  @NUSComputing Congratulations! Yaman @the_dhum...
# 99       ⚡️ “Achievements”\n\nhttps://t.co/LvZt1GTY4C
#
#                          date_time favorites retweets num_images
# 0   Wed Mar 20 08:19:24 +0000 2019         1        1       None
# 1   Wed Mar 20 02:40:07 +0000 2019         0        4       None
# 2   Mon Mar 18 02:27:47 +0000 2019         6        3       None
# 3   Sun Mar 17 14:22:04 +0000 2019        15        4       None
# 4   Sat Mar 16 14:06:56 +0000 2019         6        0       None
# 5   Sat Mar 16 09:20:29 +0000 2019         1        1       None
# 6   Sat Mar 16 09:14:58 +0000 2019         7        2       None
# 7   Sat Mar 16 05:13:14 +0000 2019         7        2       None
# 8   Wed Mar 13 17:09:44 +0000 2019         0        2       None
# 9   Wed Mar 13 04:11:24 +0000 2019         1        0          1
# 10  Wed Mar 13 04:06:04 +0000 2019         0       13       None
# 11  Tue Mar 12 17:43:44 +0000 2019         0       67       None
# 12  Tue Mar 12 14:37:55 +0000 2019        16        4          1
# 13  Mon Mar 11 14:58:30 +0000 2019         0        0       None
# 14  Mon Mar 11 12:02:42 +0000 2019         4        0       None
# 15  Mon Mar 11 11:54:38 +0000 2019         3        0       None
# 16  Mon Mar 11 06:22:12 +0000 2019         1        1       None
# 17  Mon Mar 11 06:17:20 +0000 2019         0       64       None
# 18  Fri Mar 08 13:22:07 +0000 2019         1        0       None
# 19  Fri Mar 08 13:15:34 +0000 2019         8        4       None
# 20  Wed Mar 06 13:44:11 +0000 2019         3        0       None
# 21  Wed Mar 06 11:12:30 +0000 2019         0       22          1
# 22  Sun Mar 03 19:36:04 +0000 2019         0       35       None
# 23  Sun Mar 03 17:09:48 +0000 2019         1        0       None
# 24  Sun Mar 03 15:37:28 +0000 2019         9        1          3
# 25  Sun Mar 03 14:55:31 +0000 2019         6        2       None
# 26  Sun Mar 03 14:26:40 +0000 2019         0      315       None
# 27  Sat Mar 02 17:43:05 +0000 2019         1        0       None
# 28  Sat Mar 02 09:59:03 +0000 2019         7        1       None
# 29  Thu Feb 28 14:21:21 +0000 2019         0        4          1
# ..                             ...       ...      ...        ...
# 70  Sat Feb 02 05:05:16 +0000 2019         7        3          4
# 71  Fri Feb 01 07:46:57 +0000 2019         3        1       None
# 72  Fri Feb 01 07:30:53 +0000 2019        24        3          1
# 73  Fri Feb 01 03:15:27 +0000 2019         0        8       None
# 74  Fri Feb 01 03:13:23 +0000 2019         0        2       None
# 75  Thu Jan 31 06:57:04 +0000 2019         1        1       None
# 76  Thu Jan 31 05:50:19 +0000 2019         4        2       None
# 77  Thu Jan 31 05:32:43 +0000 2019         0        2       None
# 78  Wed Jan 30 19:46:11 +0000 2019         0        2       None
# 79  Wed Jan 30 17:18:40 +0000 2019         0       11          1
# 80  Wed Jan 30 05:00:29 +0000 2019         3        1          1
# 81  Tue Jan 29 19:42:10 +0000 2019         5        2       None
# 82  Tue Jan 29 19:39:29 +0000 2019         3        1       None
# 83  Tue Jan 29 19:31:35 +0000 2019         2        1       None
# 84  Tue Jan 29 18:05:01 +0000 2019         5        2       None
# 85  Tue Jan 29 18:03:31 +0000 2019         0        5       None
# 86  Tue Jan 29 17:52:23 +0000 2019         0        2       None
# 87  Tue Jan 29 14:52:24 +0000 2019         0       33          1
# 88  Tue Jan 29 05:17:27 +0000 2019         3        1          2
# 89  Tue Jan 29 04:40:47 +0000 2019         0        5       None
# 90  Mon Jan 28 12:11:29 +0000 2019         0        8       None
# 91  Mon Jan 28 12:11:13 +0000 2019         0       19       None
# 92  Mon Jan 28 12:10:37 +0000 2019         0       68       None
# 93  Fri Jan 25 08:56:54 +0000 2019         0      141       None
# 94  Thu Jan 24 15:43:25 +0000 2019         0       24       None
# 95  Thu Jan 24 15:42:59 +0000 2019         0       25          1
# 96  Wed Jan 23 10:24:14 +0000 2019         0        0       None
# 97  Wed Jan 23 10:23:34 +0000 2019         0       10       None
# 98  Tue Jan 22 14:04:40 +0000 2019         1        1       None
# 99  Tue Jan 22 14:02:51 +0000 2019         3        1       None
#
# [100 rows x 5 columns]

# %% [markdown]
# Saving the output in .csv format

# %%
df.to_csv('tweet-output.csv', index = False)
